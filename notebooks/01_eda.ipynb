# %% [markdown]
# # Exploratory data analysis
# Inspect class imbalance, amount/time distributions, and data quality without modifying the reusable package.

# %%
from fraudshield.data import load_dataset

frame = load_dataset("../data/raw/creditcard.csv")
frame["Class"].value_counts().rename("transactions").to_frame()

# %%
frame.groupby("Class")["Amount"].describe()
