# %% [markdown]
# # Model comparison
# Read the immutable artifacts produced by `scripts.train`; do not tune on the held-out test set.

# %%
import json

import pandas as pd

metrics = json.load(open("../artifacts/model/metrics.json"))
pd.DataFrame(metrics["model_comparison"]).sort_values("cv_average_precision", ascending=False)

# %%
pd.DataFrame(metrics["threshold_comparison_validation"]).T[
    ["threshold", "precision", "recall", "decision_cost"]
]
